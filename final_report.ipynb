# %%
import os
import pandas as pd
from datetime import timedelta, datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
from sklearn.model_selection import TimeSeriesSplit
import statsmodels.api as sm
from math import sqrt 
from sklearn.metrics import mean_squared_error

import statsmodels.api as sm
from statsmodels.tsa.api import Holt, ExponentialSmoothing

import functions as f
import Acquire as a
warnings.filterwarnings("ignore")

# %% [markdown]
# # Acquire

# %%
city_df = a.get_city_df()

# %%
city_df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %% [markdown]
# **Data was acquired from Data Science Team**
# * contains null values
# * did not remove outliers

# %% [markdown]
# # Prepare

# %%
city_df= f.prep_city_data(city_df)

# %% [markdown]
# **Filled null values with .pad() function**

# %%
f.plot_1(city_df)

# %% [markdown]
# # Splitting Data

# %%
train, validate, test = f.data_split(city_df)

# %% [markdown]
# # Explore

# %%
f.explore(train, validate, test, city_df)

# %% [markdown]
# # Modeling

# %%
f.modeling(train,validate,test,city_df)
# Out:
# 18.21 1.25
# AverageTemperature -- RMSE: 12
# AverageTemperatureUncertainty -- RMSE: 1
# AverageTemperature -- RMSE: 17
# AverageTemperatureUncertainty -- RMSE: 18
# (2582, 2)
# (12, 2)
# (12, 2)
# AverageTemperature -- RMSE: 0
# AverageTemperatureUncertainty -- RMSE: 0
# FINAL PERFORMANCE OF MODEL ON TEST DATA
# rmse_average_temp_total:  17.449880813676238
# rmse-avg-temp-unc:  18.14902065064393

# %% [markdown]
# **Takeaways**
# * based on the data, it shows that the next predicted 40 years will be increasing will uncertainty is decreasing.

# %% [markdown]
# ###### Recommendations
